# %%
import pandas as pd

# %% [markdown]
# ### Initial Shape of our Data set

# %%
file_path = '/Users/miguelaraujo/code/MrAraujo99/ET_Predictor/raw_data/UFO sightings/scrubbed.csv'
data = pd.read_csv(file_path, low_memory=False)

data.shape
# Out:
# (80332, 11)

# %% [markdown]
# ### Missing data that we had to deal with

# %%
# Display basic information about the dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %% [markdown]
# #### How we dealt with the missing data(Explain)

# %%
# Strip whitespace from column names
data.columns = data.columns.str.strip()

# Convert latitude and longitude to numeric, forcing invalid parsing to NaN
data['latitude'] = pd.to_numeric(data['latitude'], errors='coerce')
data['longitude'] = pd.to_numeric(data['longitude'], errors='coerce')

# Convert duration (seconds) to numeric, forcing invalid parsing to NaN
data['duration (seconds)'] = pd.to_numeric(data['duration (seconds)'], errors='coerce')

# Convert datetime column to datetime object
data['datetime'] = pd.to_datetime(data['datetime'], errors='coerce')

# Drop rows with NaN values in datetime, duration (seconds), latitude, or longitude
data.dropna(subset=['datetime', 'duration (seconds)', 'latitude', 'longitude'], inplace=True)

# Handle missing values in state, country, and shape
# For simplicity, fill missing values with 'Unknown'
data['state'] = data['state'].fillna('Unknown')
data['country'] = data['country'].fillna('Unknown')
data['shape'] = data['shape'].fillna('Unknown')

# Display the cleaned dataset's info and first few rows to verify
cleaned_data_info = data.info()
cleaned_data_head = data.head()

cleaned_data_info
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 79634 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              79634 non-null  datetime64[ns]
#  1   city                  79634 non-null  object
#  2   state                 79634 non-null  object
#  3   country               79634 non-null  object
#  4   shape                 79634 non-null  object
#  5   duration (seconds)    79634 non-null  float64
#  6   duration (hours/min)  79634 non-null  object
#  7   comments              79619 non-null  object
#  8   date posted           79634 non-null  object
#  9   latitude              79634 non-null  float64
#  10  longitude             79634 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(7)
# memory usage: 7.3+ MB

# %% [markdown]
# ##### useless for presentation

# %%
numerical_summary = data[['duration (seconds)', 'latitude', 'longitude']].describe()
print("Numerical Summary Statistics:")
print(numerical_summary)
# Out:
# Numerical Summary Statistics:
#        duration (seconds)      latitude     longitude
# count        7.963400e+04  79634.000000  79634.000000
# mean         8.078740e+03     38.125819    -86.844174
# std          5.930974e+05     10.444614     39.577622
# min          1.000000e-03    -82.862752   -173.985008
# 25%          3.000000e+01     34.136389   -112.073333
# 50%          1.800000e+02     39.414167    -87.903611
# 75%          6.000000e+02     42.787361    -78.781389
# max          9.783600e+07     72.700000    178.441900

# %% [markdown]
# #### Shape Distribution of the forese

# %%
shape_distribution = data['shape'].value_counts()
shape_distribution
# Out:
# shape
# light        16465
# triangle      7813
# circle        7532
# fireball      6166
# other         5591
# unknown       5532
# sphere        5341
# disk          5138
# oval          3699
# formation     2442
# cigar         2033
# changing      1942
# Unknown       1889
# flash         1326
# rectangle     1286
# cylinder      1268
# diamond       1166
# chevron        949
# egg            752
# teardrop       744
# cone           315
# cross          230
# delta            7
# round            2
# crescent         2
# pyramid          1
# flare            1
# hexagon          1
# changed          1
# Name: count, dtype: int64

# %%
city_distribution = data['city'].value_counts().head(10)
city_distribution
# Out:
# city
# seattle        521
# phoenix        450
# portland       373
# las vegas      368
# los angeles    349
# san diego      335
# houston        295
# chicago        263
# tucson         241
# miami          238
# Name: count, dtype: int64

# %%
state_distribution = data['state'].value_counts()
state_distribution
# Out:
# state
# ca         9583
# Unknown    5685
# wa         4240
# fl         4175
# tx         3638
#            ...
# nf           25
# nt           20
# pe           17
# yt           13
# yk            7
# Name: count, Length: 68, dtype: int64

# %% [markdown]
# #### Reason why we chose the data only for  US AND Canada

# %%
country_distribution = data['country'].value_counts()
country_distribution
# Out:
# country
# us         64625
# Unknown     9531
# ca          2979
# gb          1865
# au           532
# de           102
# Name: count, dtype: int64

# %%
# Distribution of categorical columns

# Shape distribution
shape_distribution = data['shape'].value_counts()

# City distribution (Top 10)
city_distribution = data['city'].value_counts().head(10)

# State distribution
state_distribution = data['state'].value_counts()

# Country distribution
country_distribution = data['country'].value_counts()

shape_distribution, city_distribution, state_distribution, country_distribution
# Out:
# (shape
#  light        16465
#  triangle      7813
#  circle        7532
#  fireball      6166
#  other         5591
#  unknown       5532
#  sphere        5341
#  disk          5138
#  oval          3699
#  formation     2442
#  cigar         2033
#  changing      1942
#  Unknown       1889
#  flash         1326
#  rectangle     1286
#  cylinder      1268
#  diamond       1166
#  chevron        949
#  egg            752
#  teardrop       744
#  cone           315
#  cross          230
#  delta            7
#  round            2
#  crescent         2
#  pyramid          1
#  flare            1
#  hexagon          1
#  changed          1
#  Name: count, dtype: int64,
#  city
#  seattle        521
#  phoenix        450
#  portland       373
#  las vegas      368
#  los angeles    349
#  san diego      335
#  houston        295
#  chicago        263
#  tucson         241
#  miami          238
#  Name: count, dtype: int64,
#  state
#  ca         9583
#  Unknown    5685
#  wa         4240
#  fl         4175
#  tx         3638
#             ...
#  nf           25
#  nt           20
#  pe           17
#  yt           13
#  yk            7
#  Name: count, Length: 68, dtype: int64,
#  country
#  us         64625
#  Unknown     9531
#  ca          2979
#  gb          1865
#  au           532
#  de           102
#  Name: count, dtype: int64)

# %%
shape_distribution.head(10)
# Out:
# shape
# light        16465
# triangle      7813
# circle        7532
# fireball      6166
# other         5591
# unknown       5532
# sphere        5341
# disk          5138
# oval          3699
# formation     2442
# Name: count, dtype: int64

# %%
city_distribution
# Out:
# city
# seattle        521
# phoenix        450
# portland       373
# las vegas      368
# los angeles    349
# san diego      335
# houston        295
# chicago        263
# tucson         241
# miami          238
# Name: count, dtype: int64

# %%
state_distribution.head(10)
# Out:
# state
# ca         9583
# Unknown    5685
# wa         4240
# fl         4175
# tx         3638
# ny         3195
# az         2666
# il         2627
# pa         2567
# oh         2401
# Name: count, dtype: int64

# %%
country_distribution
# Out:
# country
# us         64625
# Unknown     9531
# ca          2979
# gb          1865
# au           532
# de           102
# Name: count, dtype: int64

# %%
# Displaying the top 10 values for shape, city, state, and country distributions

top_shape_distribution = shape_distribution.head(10)
top_city_distribution = city_distribution
top_state_distribution = state_distribution.head(10)
top_country_distribution = country_distribution

top_shape_distribution, top_city_distribution, top_state_distribution, top_country_distribution
# Out:
# (shape
#  light        16465
#  triangle      7813
#  circle        7532
#  fireball      6166
#  other         5591
#  unknown       5532
#  sphere        5341
#  disk          5138
#  oval          3699
#  formation     2442
#  Name: count, dtype: int64,
#  city
#  seattle        521
#  phoenix        450
#  portland       373
#  las vegas      368
#  los angeles    349
#  san diego      335
#  houston        295
#  chicago        263
#  tucson         241
#  miami          238
#  Name: count, dtype: int64,
#  state
#  ca         9583
#  Unknown    5685
#  wa         4240
#  fl         4175
#  tx         3638
#  ny         3195
#  az         2666
#  il         2627
#  pa         2567
#  oh         2401
#  Name: count, dtype: int64,
#  country
#  us         64625
#  Unknown     9531
#  ca          2979
#  gb          1865
#  au           532
#  de           102
#  Name: count, dtype: int64)

# %%
shape_distribution.head(10)
# Out:
# shape
# light        16465
# triangle      7813
# circle        7532
# fireball      6166
# other         5591
# unknown       5532
# sphere        5341
# disk          5138
# oval          3699
# formation     2442
# Name: count, dtype: int64

# %%
city_distribution
# Out:
# city
# seattle        521
# phoenix        450
# portland       373
# las vegas      368
# los angeles    349
# san diego      335
# houston        295
# chicago        263
# tucson         241
# miami          238
# Name: count, dtype: int64

# %%
state_distribution.head(10)
# Out:
# state
# ca         9583
# Unknown    5685
# wa         4240
# fl         4175
# tx         3638
# ny         3195
# az         2666
# il         2627
# pa         2567
# oh         2401
# Name: count, dtype: int64

# %%
country_distribution
# Out:
# country
# us         64625
# Unknown     9531
# ca          2979
# gb          1865
# au           532
# de           102
# Name: count, dtype: int64

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming `data` is your DataFrame and already cleaned

# Extract the year from the datetime column
data['year'] = data['datetime'].dt.year

# Count the number of sightings per year
sightings_per_year = data['year'].value_counts().sort_index()

# Plot the number of sightings per year
plt.figure(figsize=(12, 6))
plt.plot(sightings_per_year.index, sightings_per_year.values, marker='o')
plt.title('Number of Sightings Per Year')
plt.xlabel('Year')
plt.ylabel('Number of Sightings')
plt.grid(True)
plt.show()

# %%
# !pip install geopandas geopy
# Out:
# Requirement already satisfied: geopandas in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (0.14.4)
# Requirement already satisfied: geopy in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (2.4.1)
# Requirement already satisfied: fiona>=1.8.21 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from geopandas) (1.9.6)
# Requirement already satisfied: numpy>=1.22 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from geopandas) (1.26.4)
# Requirement already satisfied: packaging in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from geopandas) (24.0)
# Requirement already satisfied: pandas>=1.4.0 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from geopandas) (2.0.4)
# Requirement already satisfied: geographiclib<3,>=1.52 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from geopy) (2.0)
# Requirement already satisfied: attrs>=19.2.0 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (23.2.0)
# Requirement already satisfied: certifi in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (2024.6.2)
# Requirement already satisfied: click~=8.0 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from pandas>=1.4.0->geopandas) (2024.1)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
from shapely.geometry import Point

# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(data['longitude'], data['latitude'])]
geo_data = gpd.GeoDataFrame(data, geometry=geometry)

# Load world map
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# Plot the sightings on the world map
fig, ax = plt.subplots(figsize=(15, 10))
world.plot(ax=ax, color='lightgrey')

# Plot the sightings
geo_data.plot(ax=ax, markersize=1, color='red', alpha=0.5)
plt.title('Geographical Distribution of Sightings')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
# Out:
# /tmp/ipykernel_66109/2462800361.py:10: FutureWarning: The geopandas.dataset module is deprecated and will be removed in GeoPandas 1.0. You can get the original 'naturalearth_lowres' data from https://www.naturalearthdata.com/downloads/110m-cultural-vectors/.
#   world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
correlation_matrix = data[['duration (seconds)', 'latitude', 'longitude']].corr()

import seaborn as sns

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
# !pip install contextily
# Out:
# Requirement already satisfied: contextily in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (1.6.0)
# Requirement already satisfied: geopy in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from contextily) (2.4.1)
# Requirement already satisfied: matplotlib in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from contextily) (3.9.0)
# Requirement already satisfied: mercantile in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from contextily) (1.2.1)
# Requirement already satisfied: pillow in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from contextily) (10.3.0)
# Requirement already satisfied: rasterio in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from contextily) (1.3.10)
# Requirement already satisfied: requests in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from contextily) (2.32.3)
# Requirement already satisfied: joblib in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from contextily) (1.4.2)
# Requirement already satisfied: xyzservices in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from contextily) (2024.4.0)
# Requirement already satisfied: geographiclib<3,>=1.52 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from geopy->contextily) (2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from matplotlib->contextily) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from matplotlib->contextily) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from matplotlib->contextily) (4.53.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from matplotlib->contextily) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from matplotlib->contextily) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from matplotlib->contextily) (24.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from matplotlib->contextily) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from matplotlib->contextily) (2.9.0.post0)
# Requirement already satisfied: click>=3.0 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from mercantile->contextily) (8.1.7)
# Requirement already satisfied: affine in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from rasterio->contextily) (2.4.0)
# Requirement already satisfied: attrs in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from rasterio->contextily) (23.2.0)
# Requirement already satisfied: certifi in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from rasterio->contextily) (2024.6.2)
# Requirement already satisfied: cligj>=0.5 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from rasterio->contextily) (0.7.2)
# Requirement already satisfied: snuggs>=1.4.1 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from rasterio->contextily) (1.4.7)
# Requirement already satisfied: click-plugins in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from rasterio->contextily) (1.1.1)
# Requirement already satisfied: setuptools in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from rasterio->contextily) (63.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from requests->contextily) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from requests->contextily) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from requests->contextily) (2.2.1)
# Requirement already satisfied: six>=1.5 in /home/antqua/.pyenv/versions/3.10.6/envs/ET_Predictor/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->contextily) (1.16.0)

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import contextily as ctx
from shapely.geometry import Point

# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(data['longitude'], data['latitude'])]
geo_data = gpd.GeoDataFrame(data, geometry=geometry)

# Set the coordinate reference system (CRS) to WGS 84
geo_data.crs = 'EPSG:4326'

# Plot the sightings on an online basemap
fig, ax = plt.subplots(figsize=(15, 10))
geo_data.plot(ax=ax, markersize=1, color='red', alpha=0.5)

# Add basemap
ctx.add_basemap(ax, crs=geo_data.crs.to_string(), source=ctx.providers.OpenStreetMap.Mapnik)
plt.title('Geographical Distribution of Sightings')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()
